# %% [markdown]
# ## 어텐션의 구조

# %% [markdown]
# #### Decoder 개선 1

# %%
import numpy as np
T, H = 5, 4
hs = np.random.randn(T, H)
a = np.array([0.8, 0.1, 0.03, 0.05, 0.02])

ar = a.reshape(5, 1).repeat(4, axis = 1)
print(ar.shape)

t = hs * ar
print(t.shape)

c = np.sum(t, axis = 0)
print(c.shape)
# Out:
# (5, 4)
# (5, 4)
# (4,)

# %%
# 미니배치 처리용 가중합
N, T, H = 10, 5, 4
hs = np.random.randn(N, T, H)
a = np.random.randn(N, T)
ar = a.reshape(N, T, 1).repeat(H, axis = 2)

t = hs * ar
print(t.shape)

c = np.sum(t, axis = 0)
print(c.shape)
# Out:
# (10, 5, 4)
# (5, 4)

# %%
class WeightSum:
  def __init__(self):
    self.params, self.grads = [], []
    self.cache = None

  def forward(self, hs, a):
    N, T, H = hs.shape

    ar = a.reshape(N, T, 1).repeat(H, axis = 2)
    t = hs * ar
    c = np.sum(t, axis = 1)

    self.cache = (hs, ar)
    return c

  def backward(self, dc):
    hs, ar = self.cache
    N, T, H = hs.shape

    dt = dc.reshape(N, 1, H).repeat(T, axis = 1)      # sum의 역전파
    dar = dt * hs
    dhs = dt * ar
    da = np.sum(dar, axis = 2)                        # repeat의 역전파

    return dhs, da

# %% [markdown]
# #### Decoder 개선 2

# %%
# %cd /content/drive/MyDrive/colab/deep_learning_basic/밑바닥부터_시작하는_딥러닝2
# Out:
# /content/drive/MyDrive/colab/deep_learning_basic/밑바닥부터_시작하는_딥러닝2

# %%
import sys
sys.path.append('..')
from common.layers import Softmax
import numpy as np

N, T, H = 10, 5, 4
hs = np.random.randn(N, T, H)
h = np.random.randn(N, H)
hr = h.reshape(N, 1, H).repeat(T, axis = 1)

t = hs * hr
print(t.shape)

s = np.sum(t, axis = 2)
print(s.shape)

softmax = Softmax()
a = softmax.forward(s)
print(a.shape)
# Out:
# (10, 5, 4)
# (10, 5)
# (10, 5)

# %%
import sys
sys.path.append('..')
from common.np import *
from common.layers import Softmax

class AttentionWeight:
  def __init__(self):
    self.params, self.grads = [], []
    self.softmax = Softmax()
    self.cache = None

  def forward(self, hs, h):
    N, T, H = hs.shape

    hr = h.reshape(N, 1, H).repeat(T, axis = 1)
    t = hs * hr
    s = np.sum(t, axis = 2)
    a = self.softmax.forward(s)

    self.cache = (hs, hr)
    return a

  def backward(self, da):
    hs, hr = self.cache
    N, T, H = hs.shape

    ds = self.softmax.backward(da)
    dt = ds.reshape(N, T, 1).repeat(H, axis = 2)
    dhs = dt * hr
    dhr = dt * hs
    dh = np.sum(dhr, axis = 1)

    return dhs, dh

# %% [markdown]
# #### Decoder 개선 3

# %%
class Attention:
  def __init__(self):
    self.params, self.grads = [], []
    self.attention_weight_layer = AttentionWeight()
    self.weight_sum_layer = WeightSum()
    self.attention_weight = None

  def forward(self, hs, h):
    a = self.attention_weight_layer.forward(hs, h)
    out = self.weight_sum_layer.forward(hs, a)
    self.attention_weight = a
    return out

  def backward(self, dout):
    dhs0, da = self.weight_sum_layer.backward(dout)
    dhs1, dh = self.attention_weight_layer.backward(da)
    dhs = dhs0 + dhs1
    return dhs, dh

# %%
class TimeAttention:
  def __init__(self):
    self.params, self.grads = [], []
    self.layers = None
    self.attention_weights = None

  def forward(self, hs_enc, hs_dec):
    N, T, H = hs_dec.shape
    out = np.empty_like(hs_dec)
    self.layers = []
    self.attention_weights = []

    for t in range(T):
      layer = Attention()
      out[:, t, :] = layer.forward(hs_enc, hs_dec[:, t, :])
      self.layers.append(layer)
      self.attenion_weights.append(layer.attention_weight)

    return out

  def backward(self, dout):
    N, T, H = dout.shape
    dhs_enc = 0
    dhs_dec = np.empty_like(dout)

    for t in range(T):
      layer = self.layers[t]
      dhs, dh = layer.backward(dout[:, t, :])
      dhs_enc += dhs
      dhs_dec[:, t, :] = dh

    return dhs_enc, dhs_dec

# %% [markdown]
# ## 어텐션을 갖춘 seq2seq 구현

# %% [markdown]
# #### Encoder 구현

# %%
import sys
sys.path.append('..')
from common.time_layers import *
from ch07.seq2seq import Encoder, Seq2seq
from ch08.attention_layer import TimeAttention

class AttentionEncoder(Encoder):
  def forward(self, xs):
    xs = self.embed.forward(xs)
    hs = self.lstm.forward(xs)
    return hs

  def backward(self, dhs):
    dout = self.lstm.backward(dhs)
    dout = self.embed.backward(dout)
    return dout

# %% [markdown]
# #### Decoder 구현

# %%
class AttentionDecoder:
  def __init__(self, vocab_size, wordvec_size, hidden_size):
    V, D, H = vocab_size, wordvec_size, hidden_size
    rn = np.random.randn
    embed_W = (rn(V, D) / 100).astype('f')
    lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
    lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
    lstm_b = np.zeros(4 * H).astype('f')
    affine_W = (rn(2 * H, V) / np.sqrt(2 * H)).astype('f')
    affine_b = np.zeros(V).astype('f')

    self.embed = TimeEmbedding(embed_W)
    self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful = True)
    self.attention = TimeAttention()
    self.affine = TimeAffine(affine_W, affine_b)
    layers = [self.embed, self.lstm, self.attention, self.affine]

    self.params, self.grads = [], []
    for layer in layers:
      self.params += layer.params
      self.grads += layer.grads

  def forward(self, xs, enc_hs):
    h = enc_hs[:, -1]
    self.lstm.set_state(h)

    out = self.embed.forward(xs)
    dec_hs = self.lstm.forward(out)
    c = self.attention.forward(enc_hs, dec_hs)
    out = np.concatenate((c, dec_hs), axis = 2)
    score = self.affine.forward(out)

    return score

  def backward(self, dscore):
    dout = self.affine.backward(dscore)
    N, T, H2 = dout.shape
    H = H2 // 2

    dc, ddec_hs0 = dout[:, :, :H], dout[:, :, H:]
    denc_hs, ddec_hs1 = self.attention.backward(dc)
    ddec_hs = ddec_hs0 + ddec_hs1
    dout = self.lstm.backward(ddec_hs)
    dh = self.lstm.dh
    denc_hs[:, -1] += dh
    self.embed.backward(dout)

    return denc_hs

  def generate(self, enc_hs, start_id, sample_size):
    sampled = []
    sample_id = start_id
    h = enc_hs[:, -1]
    self.lstm.set_state(h)

    for _ in range(sample_size):
      x = np.array([sample_id]).reshape((1, 1))

      out = self.embed.forward(x)
      dec_hs = self.lstm.forward(out)
      c = self.attention.forward(enc_hs, dec_hs)
      out = np.concatenate((c, dec_hs), axis = 2)
      score = self.affine.forward(out)

      sample_id = np.argmax(score.flatten())
      sampled.append(sample_id)

    return sampled

# %% [markdown]
# #### seq2seq 구현

# %%
from ch07.seq2seq import Encoder, Seq2seq

class AttentionSeq2seq(Seq2seq):
  def __init__(self, vocab_size, wordvec_size, hidden_size):
    args = vocab_size, wordvec_size, hidden_size
    self.encoder = AttentionEncoder(*args)
    self.decoder = AttentionDecoder(*args)
    self.softmax = TimeSoftmaxWithLoss()

    self.params = self.encoder.params + self.decoder.params
    self.grads = self.encoder.grads + self.decoder.grads

# %% [markdown]
# ## 어텐션 평가

# %% [markdown]
# #### 어텐션을 갖춘 seq2seq의 학습

# %%
import sys
sys.path.append('..')
sys.path.append('../ch07')
import numpy as np
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from ch08.attention_seq2seq import AttentionSeq2seq
from ch07.seq2seq import Seq2seq
from ch07.peeky_seq2seq import PeekySeq2seq

# 데이터 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 문장 반전
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256
batch_size = 128
max_epoch = 10
max_grad = 5.0

model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
  trainer.fit(x_train, t_train, max_epoch = 1, batch_size = batch_size, max_grad = max_grad)

  correct_num = 0
  for i in range(len(x_test)):
    question, correct = x_test[[i]], t_test[[i]]
    verbose = i < 10
    correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose, is_reverse = True)

  acc = float(correct_num) / len(x_test)
  acc_list.append(acc)
  print(f'val acc: {acc * 100:.3f}%')

model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 13[s] | 손실 3.09
# | 에폭 1 |  반복 41 / 351 | 시간 26[s] | 손실 1.90
# | 에폭 1 |  반복 61 / 351 | 시간 39[s] | 손실 1.72
# | 에폭 1 |  반복 81 / 351 | 시간 52[s] | 손실 1.46
# | 에폭 1 |  반복 101 / 351 | 시간 65[s] | 손실 1.19
# | 에폭 1 |  반복 121 / 351 | 시간 77[s] | 손실 1.14
# | 에폭 1 |  반복 141 / 351 | 시간 90[s] | 손실 1.09
# | 에폭 1 |  반복 161 / 351 | 시간 102[s] | 손실 1.06
# | 에폭 1 |  반복 181 / 351 | 시간 115[s] | 손실 1.04
# | 에폭 1 |  반복 201 / 351 | 시간 127[s] | 손실 1.03
# | 에폭 1 |  반복 221 / 351 | 시간 140[s] | 손실 1.02
# | 에폭 1 |  반복 241 / 351 | 시간 152[s] | 손실 1.02
# | 에폭 1 |  반복 261 / 351 | 시간 165[s] | 손실 1.01
# | 에폭 1 |  반복 281 / 351 | 시간 177[s] | 손실 1.00
# | 에폭 1 |  반복 301 / 351 | 시간 190[s] | 손실 1.00
# | 에폭 1 |  반복 321 / 351 | 시간 202[s] | 손실 1.00
# | 에폭 1 |  반복 341 / 351 | 시간 214[s] | 손실 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-08-11
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1978-08-11
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1978-08-11
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1978-08-11
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1978-08-11
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1978-08-11
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1978-08-11
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1978-08-11
# ---
# val acc: 0.000%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 2 |  반복 21 / 351 | 시간 13[s] | 손실 1.00
# | 에폭 2 |  반복 41 / 351 | 시간 26[s] | 손실 0.99
# | 에폭 2 |  반복 61 / 351 | 시간 38[s] | 손실 0.99
# | 에폭 2 |  반복 81 / 351 | 시간 51[s] | 손실 0.99
# | 에폭 2 |  반복 101 / 351 | 시간 63[s] | 손실 0.99
# | 에폭 2 |  반복 121 / 351 | 시간 76[s] | 손실 0.99
# | 에폭 2 |  반복 141 / 351 | 시간 88[s] | 손실 0.98
# | 에폭 2 |  반복 161 / 351 | 시간 101[s] | 손실 0.98
# | 에폭 2 |  반복 181 / 351 | 시간 113[s] | 손실 0.97
# | 에폭 2 |  반복 201 / 351 | 시간 125[s] | 손실 0.95
# | 에폭 2 |  반복 221 / 351 | 시간 138[s] | 손실 0.94
# | 에폭 2 |  반복 241 / 351 | 시간 150[s] | 손실 0.90
# | 에폭 2 |  반복 261 / 351 | 시간 162[s] | 손실 0.83
# | 에폭 2 |  반복 281 / 351 | 시간 174[s] | 손실 0.74
# | 에폭 2 |  반복 301 / 351 | 시간 187[s] | 손실 0.66
# | 에폭 2 |  반복 321 / 351 | 시간 199[s] | 손실 0.58
# | 에폭 2 |  반복 341 / 351 | 시간 211[s] | 손실 0.47
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 2006-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 2007-08-09
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1983-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 2016-11-08
# ---
# val acc: 51.240%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 3 |  반복 21 / 351 | 시간 12[s] | 손실 0.30
# | 에폭 3 |  반복 41 / 351 | 시간 23[s] | 손실 0.21
# | 에폭 3 |  반복 61 / 351 | 시간 34[s] | 손실 0.14
# | 에폭 3 |  반복 81 / 351 | 시간 45[s] | 손실 0.09
# | 에폭 3 |  반복 101 / 351 | 시간 57[s] | 손실 0.07
# | 에폭 3 |  반복 121 / 351 | 시간 68[s] | 손실 0.05
# | 에폭 3 |  반복 141 / 351 | 시간 80[s] | 손실 0.04
# | 에폭 3 |  반복 161 / 351 | 시간 91[s] | 손실 0.03
# | 에폭 3 |  반복 181 / 351 | 시간 102[s] | 손실 0.03
# | 에폭 3 |  반복 201 / 351 | 시간 114[s] | 손실 0.02
# | 에폭 3 |  반복 221 / 351 | 시간 125[s] | 손실 0.02
# | 에폭 3 |  반복 241 / 351 | 시간 136[s] | 손실 0.02
# | 에폭 3 |  반복 261 / 351 | 시간 148[s] | 손실 0.01
# | 에폭 3 |  반복 281 / 351 | 시간 159[s] | 손실 0.01
# | 에폭 3 |  반복 301 / 351 | 시간 171[s] | 손실 0.01
# | 에폭 3 |  반복 321 / 351 | 시간 182[s] | 손실 0.01
# | 에폭 3 |  반복 341 / 351 | 시간 193[s] | 손실 0.01
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 99.900%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 4 |  반복 21 / 351 | 시간 11[s] | 손실 0.01
# | 에폭 4 |  반복 41 / 351 | 시간 23[s] | 손실 0.01
# | 에폭 4 |  반복 61 / 351 | 시간 34[s] | 손실 0.01
# | 에폭 4 |  반복 81 / 351 | 시간 46[s] | 손실 0.01
# | 에폭 4 |  반복 101 / 351 | 시간 57[s] | 손실 0.01
# | 에폭 4 |  반복 121 / 351 | 시간 69[s] | 손실 0.00
# | 에폭 4 |  반복 141 / 351 | 시간 80[s] | 손실 0.01
# | 에폭 4 |  반복 161 / 351 | 시간 91[s] | 손실 0.00
# | 에폭 4 |  반복 181 / 351 | 시간 103[s] | 손실 0.00
# | 에폭 4 |  반복 201 / 351 | 시간 114[s] | 손실 0.00
# | 에폭 4 |  반복 221 / 351 | 시간 125[s] | 손실 0.00
# | 에폭 4 |  반복 241 / 351 | 시간 137[s] | 손실 0.00
# | 에폭 4 |  반복 261 / 351 | 시간 148[s] | 손실 0.00
# | 에폭 4 |  반복 281 / 351 | 시간 160[s] | 손실 0.00
# | 에폭 4 |  반복 301 / 351 | 시간 171[s] | 손실 0.00
# | 에폭 4 |  반복 321 / 351 | 시간 183[s] | 손실 0.00
# | 에폭 4 |  반복 341 / 351 | 시간 195[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 99.900%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 5 |  반복 21 / 351 | 시간 12[s] | 손실 0.00
# | 에폭 5 |  반복 41 / 351 | 시간 23[s] | 손실 0.00
# | 에폭 5 |  반복 61 / 351 | 시간 35[s] | 손실 0.00
# | 에폭 5 |  반복 81 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 5 |  반복 101 / 351 | 시간 58[s] | 손실 0.00
# | 에폭 5 |  반복 121 / 351 | 시간 69[s] | 손실 0.00
# | 에폭 5 |  반복 141 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 5 |  반복 161 / 351 | 시간 92[s] | 손실 0.00
# | 에폭 5 |  반복 181 / 351 | 시간 104[s] | 손실 0.00
# | 에폭 5 |  반복 201 / 351 | 시간 116[s] | 손실 0.00
# | 에폭 5 |  반복 221 / 351 | 시간 128[s] | 손실 0.00
# | 에폭 5 |  반복 241 / 351 | 시간 139[s] | 손실 0.00
# | 에폭 5 |  반복 261 / 351 | 시간 151[s] | 손실 0.00
# | 에폭 5 |  반복 281 / 351 | 시간 163[s] | 손실 0.00
# | 에폭 5 |  반복 301 / 351 | 시간 175[s] | 손실 0.00
# | 에폭 5 |  반복 321 / 351 | 시간 187[s] | 손실 0.00
# | 에폭 5 |  반복 341 / 351 | 시간 199[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 99.960%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 6 |  반복 21 / 351 | 시간 12[s] | 손실 0.00
# | 에폭 6 |  반복 41 / 351 | 시간 23[s] | 손실 0.00
# | 에폭 6 |  반복 61 / 351 | 시간 35[s] | 손실 0.00
# | 에폭 6 |  반복 81 / 351 | 시간 47[s] | 손실 0.00
# | 에폭 6 |  반복 101 / 351 | 시간 58[s] | 손실 0.00
# | 에폭 6 |  반복 121 / 351 | 시간 70[s] | 손실 0.00
# | 에폭 6 |  반복 141 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 6 |  반복 161 / 351 | 시간 93[s] | 손실 0.00
# | 에폭 6 |  반복 181 / 351 | 시간 104[s] | 손실 0.00
# | 에폭 6 |  반복 201 / 351 | 시간 116[s] | 손실 0.00
# | 에폭 6 |  반복 221 / 351 | 시간 127[s] | 손실 0.00
# | 에폭 6 |  반복 241 / 351 | 시간 139[s] | 손실 0.00
# | 에폭 6 |  반복 261 / 351 | 시간 150[s] | 손실 0.00
# | 에폭 6 |  반복 281 / 351 | 시간 162[s] | 손실 0.00
# | 에폭 6 |  반복 301 / 351 | 시간 173[s] | 손실 0.05
# | 에폭 6 |  반복 321 / 351 | 시간 185[s] | 손실 0.02
# | 에폭 6 |  반복 341 / 351 | 시간 197[s] | 손실 0.01
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 99.920%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 7 |  반복 21 / 351 | 시간 11[s] | 손실 0.00
# | 에폭 7 |  반복 41 / 351 | 시간 23[s] | 손실 0.00
# | 에폭 7 |  반복 61 / 351 | 시간 34[s] | 손실 0.00
# | 에폭 7 |  반복 81 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 7 |  반복 101 / 351 | 시간 57[s] | 손실 0.00
# | 에폭 7 |  반복 121 / 351 | 시간 68[s] | 손실 0.00
# | 에폭 7 |  반복 141 / 351 | 시간 80[s] | 손실 0.00
# | 에폭 7 |  반복 161 / 351 | 시간 91[s] | 손실 0.00
# | 에폭 7 |  반복 181 / 351 | 시간 103[s] | 손실 0.00
# | 에폭 7 |  반복 201 / 351 | 시간 114[s] | 손실 0.00
# | 에폭 7 |  반복 221 / 351 | 시간 125[s] | 손실 0.00
# | 에폭 7 |  반복 241 / 351 | 시간 137[s] | 손실 0.00
# | 에폭 7 |  반복 261 / 351 | 시간 148[s] | 손실 0.00
# | 에폭 7 |  반복 281 / 351 | 시간 160[s] | 손실 0.00
# | 에폭 7 |  반복 301 / 351 | 시간 171[s] | 손실 0.00
# | 에폭 7 |  반복 321 / 351 | 시간 182[s] | 손실 0.00
# | 에폭 7 |  반복 341 / 351 | 시간 194[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 100.000%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 8 |  반복 21 / 351 | 시간 11[s] | 손실 0.00
# | 에폭 8 |  반복 41 / 351 | 시간 23[s] | 손실 0.00
# | 에폭 8 |  반복 61 / 351 | 시간 34[s] | 손실 0.00
# | 에폭 8 |  반복 81 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 8 |  반복 101 / 351 | 시간 57[s] | 손실 0.00
# | 에폭 8 |  반복 121 / 351 | 시간 69[s] | 손실 0.00
# | 에폭 8 |  반복 141 / 351 | 시간 80[s] | 손실 0.00
# | 에폭 8 |  반복 161 / 351 | 시간 91[s] | 손실 0.00
# | 에폭 8 |  반복 181 / 351 | 시간 103[s] | 손실 0.00
# | 에폭 8 |  반복 201 / 351 | 시간 114[s] | 손실 0.00
# | 에폭 8 |  반복 221 / 351 | 시간 126[s] | 손실 0.00
# | 에폭 8 |  반복 241 / 351 | 시간 137[s] | 손실 0.00
# | 에폭 8 |  반복 261 / 351 | 시간 149[s] | 손실 0.00
# | 에폭 8 |  반복 281 / 351 | 시간 160[s] | 손실 0.00
# | 에폭 8 |  반복 301 / 351 | 시간 171[s] | 손실 0.00
# | 에폭 8 |  반복 321 / 351 | 시간 183[s] | 손실 0.00
# | 에폭 8 |  반복 341 / 351 | 시간 194[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 100.000%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 9 |  반복 21 / 351 | 시간 11[s] | 손실 0.00
# | 에폭 9 |  반복 41 / 351 | 시간 23[s] | 손실 0.00
# | 에폭 9 |  반복 61 / 351 | 시간 34[s] | 손실 0.00
# | 에폭 9 |  반복 81 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 9 |  반복 101 / 351 | 시간 57[s] | 손실 0.00
# | 에폭 9 |  반복 121 / 351 | 시간 69[s] | 손실 0.00
# | 에폭 9 |  반복 141 / 351 | 시간 80[s] | 손실 0.00
# | 에폭 9 |  반복 161 / 351 | 시간 91[s] | 손실 0.00
# | 에폭 9 |  반복 181 / 351 | 시간 103[s] | 손실 0.00
# | 에폭 9 |  반복 201 / 351 | 시간 114[s] | 손실 0.00
# | 에폭 9 |  반복 221 / 351 | 시간 126[s] | 손실 0.00
# | 에폭 9 |  반복 241 / 351 | 시간 137[s] | 손실 0.00
# | 에폭 9 |  반복 261 / 351 | 시간 149[s] | 손실 0.00
# | 에폭 9 |  반복 281 / 351 | 시간 160[s] | 손실 0.00
# | 에폭 9 |  반복 301 / 351 | 시간 171[s] | 손실 0.00
# | 에폭 9 |  반복 321 / 351 | 시간 183[s] | 손실 0.00
# | 에폭 9 |  반복 341 / 351 | 시간 195[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 100.000%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 10 |  반복 21 / 351 | 시간 11[s] | 손실 0.00
# | 에폭 10 |  반복 41 / 351 | 시간 23[s] | 손실 0.00
# | 에폭 10 |  반복 61 / 351 | 시간 34[s] | 손실 0.00
# | 에폭 10 |  반복 81 / 351 | 시간 46[s] | 손실 0.00
# | 에폭 10 |  반복 101 / 351 | 시간 57[s] | 손실 0.00
# | 에폭 10 |  반복 121 / 351 | 시간 69[s] | 손실 0.00
# | 에폭 10 |  반복 141 / 351 | 시간 80[s] | 손실 0.00
# | 에폭 10 |  반복 161 / 351 | 시간 92[s] | 손실 0.00
# | 에폭 10 |  반복 181 / 351 | 시간 103[s] | 손실 0.00
# | 에폭 10 |  반복 201 / 351 | 시간 115[s] | 손실 0.00
# | 에폭 10 |  반복 221 / 351 | 시간 126[s] | 손실 0.00
# | 에폭 10 |  반복 241 / 351 | 시간 138[s] | 손실 0.00
# | 에폭 10 |  반복 261 / 351 | 시간 150[s] | 손실 0.00
# | 에폭 10 |  반복 281 / 351 | 시간 161[s] | 손실 0.00
# | 에폭 10 |  반복 301 / 351 | 시간 173[s] | 손실 0.00
# | 에폭 10 |  반복 321 / 351 | 시간 184[s] | 손실 0.00
# | 에폭 10 |  반복 341 / 351 | 시간 196[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# val acc: 100.000%

# %%
# 그래프 그리기
import matplotlib.pyplot as plt

x = np.arange(len(acc_list))
plt.figure(figsize = (12, 8))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epochs', fontsize = 12)
plt.ylabel('accuracy', fontsize = 12)
plt.ylim(-0.05, 1.05)
plt.show()

# %% [markdown]
# #### 어텐션 시각화

# %%
import sys
sys.path.append('..')
import numpy as np
from dataset import sequence
import matplotlib.pyplot as plt
from ch08.attention_seq2seq import AttentionSeq2seq

# 데이터 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 문장 반전
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256

model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
model.load_params()

_idx = 0
def visualize(attention_map, row_labels, column_labels):
  fig, ax = plt.subplots()
  ax.pcolor(attention_map, cmap = plt.cm.Greys_r, vmin = 0.0, vmax = 1.0)
  
  ax.patch.set_facecolor('black')
  ax.set_yticks(np.arange(attention_map.shape[0]) + 0.5, minor = False)
  ax.set_xticks(np.arange(attention_map.shape[1]) + 0.5, minor = False)
  ax.invert_yaxis()
  ax.set_xticklabels(row_labels, minor = False)
  ax.set_yticklabels(column_labels, minor = False)

  global _idx
  _idx += 1
  plt.show()

np.random.seed(220207)
for _ in range(5):
  idx = [np.random.randint(0, len(x_test))]
  x = x_test[idx]
  t = t_test[idx]

  model.forward(x, t)
  d = model.decoder.attention.attention_weights
  d = np.array(d)
  attention_map = d.reshape(d.shape[0], d.shape[2])

  # 출력학 위해 반전
  attention_map = attention_map[:, ::-1]
  x = x[:, ::-1]

  row_labels = [id_to_char[i] for i in x[0]]
  column_labels = [id_to_char[i] for i in t[0]]
  column_labels = column_labels[1:]

  visualize(attention_map, row_labels, column_labels)

# %% [markdown]
# ## 정리
#
# - 번역이나 음성 인식 등, 한 시계열 데이터를 다른 시계열 데이터로 변환하는 작업에서는 시계열 데이터 사이의 대응 관계가 존재하는 경우가 많다.
# - 어텐션은 두 시계열 데이터 사이의 대응 관계를 데이터로부터 학습한다.
# - 어텐션에서는 (하나의 방법으로서) 벡터의 내적을 사용해 벡터 사이의 유사도를 구하고, 그 유사도를 이용한 가중합 벡터가 어텐션의 출력이 된다.
# - 어텐션에서는 사용하는 연산은 미분 가능하기 때문에 오차역전파법으로 학습할 수 있다.
# - 어텐션이 산출하는 가중치(확률)를 시각화하면 입출력의 대응 관계를 볼 수 있다.
# - 외부 메모리를 활용한 신경망 확장 연구 예에서는 메모리를 읽고 쓰는 데 어텐션을 사용했다.
